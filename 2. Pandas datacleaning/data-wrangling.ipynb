# %% [markdown]
# # Pandas Project - cleaning shark attacks csv

# %% [markdown]
# ## Workflow determination
# 1. Determine steps to be taken
# 2. Set up csv in pandas and create copy to work with
# 3. Declare helper functions
# 3. Gather information about shape and characteristics of dataframe
# 6. Check data types
# 4. Inspect data
# 9. Check null values
# 5. Change column names
# 8. Remove duplicates
# 10. Remove irrelevant columns
# 11. Convert dates
# 12. Clean data for various columns
# 12. Correct data types
# 14. Set new index according to unique tracker
# 15. Export to new csv

# %% [markdown]
# ## Set up
#
#
# First we import the necessary libraries

# %%
import re

import numpy as np
import pandas as pd

from string import punctuation
from datetime import datetime

# %% [markdown]
# Now we declare helper functions

# %%
def clean_col_names(df):
    """Take a dataframe and return sanitized column names."""

    table = str.maketrans(dict.fromkeys(punctuation))
    return [c.lower()
             .strip()
             .translate(table)
             .replace(" ", "_") for c in df.columns]


def cols_missing_value(df):
    """Return percentage of column missing value."""
    
    return ((df.isna().sum())[df.isna().sum() > 0] / len(df)) * 100

def invalid_year(date):
    """Return NaT if not valid year."""
    
    # Doesn't work because of 20 non-cooperating rows
    if date == date:
        if date > datetime.strptime('2020', '%y'):
            return pd.NaT
    return date

def search_and_set(df, col, word, regex=False, lst=[]):
    """Search for term and set correspending rows to value."""
    
    # If lst is set, we use every term therein, otherwise just 
    # set word as first item
        
    if not lst:
        lst = [word]
    
    if regex:
        for item in lst:
            df.loc[df[col].str.contains(
                item, case=False, na=False, regex=True), col] = word
    else:
        for item in lst:
            df.loc[df[col].str.contains(
                item, case=False, na=False), col] = word

def regex_test(txt, pat, needle=False):
    """Return NaN if string does not contain pattern."""
    
    check = re.search(pat, str(txt))
    if check:
        # With needle set to True we return the part of matched string
        return check.group() if needle else txt
    return np.NaN

# %% [markdown]
# Next we import the csv into pandas and inspect the head

# %%
# Because of unicode characters we need to specify the encoding
df_original = pd.read_csv("attacks.csv", encoding="cp1252")

# We save a copy of the dataframe, just in case.
df = df_original.copy()
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Inspect

# %%
# rows and columns
df.shape
# Out:
# (25723, 24)

# %%
# Datatypes of columns
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
# Random sample of data
df.sample(20)
# Out:
#         Case Number         Date    Year        Type    Country  \
# 8382              0          NaN     NaN         NaN        NaN
# 2122     1999.06.09  09-Jun-1999  1999.0  Unprovoked        USA
# 12387           NaN          NaN     NaN         NaN        NaN
# 7011              0          NaN     NaN         NaN        NaN
# 10950           NaN          NaN     NaN         NaN        NaN
# 24394           NaN          NaN     NaN         NaN        NaN
# 21833           NaN          NaN     NaN         NaN        NaN
# 409      2015.06.23  23-Jun-2015  2015.0  Unprovoked        USA
# 13806           NaN          NaN     NaN         NaN        NaN
# 6282        ND.0020   1920 -1923     0.0  Unprovoked  AUSTRALIA
# 9502            NaN          NaN     NaN         NaN        NaN
# 11828           NaN          NaN     NaN         NaN        NaN
# 3632   1965.04.04.a  04-Apr-1965  1965.0  Unprovoked        USA
# 19513           NaN          NaN     NaN         NaN        NaN
# 15695           NaN          NaN     NaN         NaN        NaN
# 15780           NaN          NaN     NaN         NaN        NaN
# 13000           NaN          NaN     NaN         NaN        NaN
# 8343              0          NaN     NaN         NaN        NaN
# 17215           NaN          NaN     NaN         NaN        NaN
# 24263           NaN          NaN     NaN         NaN        NaN
#
#                  Area                                           Location  \
# 8382              NaN                                                NaN
# 2122          Florida  Atlantic Dunes Park, Delray Beach, Palm Beach ...
# 12387             NaN                                                NaN
# 7011              NaN                                                NaN
# 10950             NaN                                                NaN
# 24394             NaN                                                NaN
# 21833             NaN                                                NaN
# 409    South Carolina                 St. Helena Island, Beaufort County
# 13806             NaN                                                NaN
# 6282       Queensland                                 Great Barrier Reef
# 9502              NaN                                                NaN
# 11828             NaN                                                NaN
# 3632          Florida                      Juno Beach, Palm Beach County
# 19513             NaN                                                NaN
# 15695             NaN                                                NaN
# 15780             NaN                                                NaN
# 13000             NaN                                                NaN
# 8343              NaN                                                NaN
# 17215             NaN                                                NaN
# 24263             NaN                                                NaN
#
#                     Activity                 Name Sex   ...  \
# 8382                     NaN                  NaN  NaN  ...
# 2122      Splashing / wading         Ryan Welborn    M  ...
# 12387                    NaN                  NaN  NaN  ...
# 7011                     NaN                  NaN  NaN  ...
# 10950                    NaN                  NaN  NaN  ...
# 24394                    NaN                  NaN  NaN  ...
# 21833                    NaN                  NaN  NaN  ...
# 409                 Standing                 male    M  ...
# 13806                    NaN                  NaN  NaN  ...
# 6282                     NaN    3 Japanese divers    M  ...
# 9502                     NaN                  NaN  NaN  ...
# 11828                    NaN                  NaN  NaN  ...
# 3632   Paddling on surfboard  William F. Lachmund    M  ...
# 19513                    NaN                  NaN  NaN  ...
# 15695                    NaN                  NaN  NaN  ...
# 15780                    NaN                  NaN  NaN  ...
# 13000                    NaN                  NaN  NaN  ...
# 8343                     NaN                  NaN  NaN  ...
# 17215                    NaN                  NaN  NaN  ...
# 24263                    NaN                  NaN  NaN  ...
#
#                         Species                       Investigator or Source  \
# 8382                         NaN                                         NaN
# 2122   Blacktip or spinner shark                  Palm Beach Post, 6/10/1999
# 12387                        NaN                                         NaN
# 7011                         NaN                                         NaN
# 10950                        NaN                                         NaN
# 24394                        NaN                                         NaN
# 21833                        NaN                                         NaN
# 409                  small shark  C. Creswell, GSAF; R. Lurye, Island Packet
# 13806                        NaN                                         NaN
# 6282                         NaN                V.M. Coppleson (1958), p.241
# 9502                         NaN                                         NaN
# 11828                        NaN                                         NaN
# 3632   Blacktip or spinner shark          M. Vorenberg, GSAF. R. Greer, M.D.
# 19513                        NaN                                         NaN
# 15695                        NaN                                         NaN
# 15780                        NaN                                         NaN
# 13000                        NaN                                         NaN
# 8343                         NaN                                         NaN
# 17215                        NaN                                         NaN
# 24263                        NaN                                         NaN
#
#                                pdf  \
# 8382                           NaN
# 2122       1999.06.09-Wellborn.pdf
# 12387                          NaN
# 7011                           NaN
# 10950                          NaN
# 24394                          NaN
# 21833                          NaN
# 409       2015.06.23-Davenport.pdf
# 13806                          NaN
# 6282   ND-0020-3JapaneseDivers.pdf
# 9502                           NaN
# 11828                          NaN
# 3632     1965.04.04.a-Lachmund.pdf
# 19513                          NaN
# 15695                          NaN
# 15780                          NaN
# 13000                          NaN
# 8343                           NaN
# 17215                          NaN
# 24263                          NaN
#
#                                             href formula  \
# 8382                                                 NaN
# 2122   http://sharkattackfile.net/spreadsheets/pdf_di...
# 12387                                                NaN
# 7011                                                 NaN
# 10950                                                NaN
# 24394                                                NaN
# 21833                                                NaN
# 409    http://sharkattackfile.net/spreadsheets/pdf_di...
# 13806                                                NaN
# 6282   http://sharkattackfile.net/spreadsheets/pdf_di...
# 9502                                                 NaN
# 11828                                                NaN
# 3632   http://sharkattackfile.net/spreadsheets/pdf_di...
# 19513                                                NaN
# 15695                                                NaN
# 15780                                                NaN
# 13000                                                NaN
# 8343                                                 NaN
# 17215                                                NaN
# 24263                                                NaN
#
#                                                     href Case Number.1  \
# 8382                                                 NaN           NaN
# 2122   http://sharkattackfile.net/spreadsheets/pdf_di...    1999.06.09
# 12387                                                NaN           NaN
# 7011                                                 NaN           NaN
# 10950                                                NaN           NaN
# 24394                                                NaN           NaN
# 21833                                                NaN           NaN
# 409    http://sharkattackfile.net/spreadsheets/pdf_di...    2015.06.23
# 13806                                                NaN           NaN
# 6282   http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0020
# 9502                                                 NaN           NaN
# 11828                                                NaN           NaN
# 3632   http://sharkattackfile.net/spreadsheets/pdf_di...  1965.04.04.a
# 19513                                                NaN           NaN
# 15695                                                NaN           NaN
# 15780                                                NaN           NaN
# 13000                                                NaN           NaN
# 8343                                                 NaN           NaN
# 17215                                                NaN           NaN
# 24263                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 8382            NaN            NaN         NaN         NaN
# 2122     1999.06.09         4181.0         NaN         NaN
# 12387           NaN            NaN         NaN         NaN
# 7011            NaN            NaN         NaN         NaN
# 10950           NaN            NaN         NaN         NaN
# 24394           NaN            NaN         NaN         NaN
# 21833           NaN            NaN         NaN         NaN
# 409      2015.06.23         5894.0         NaN         NaN
# 13806           NaN            NaN         NaN         NaN
# 6282        ND.0020           21.0         NaN         NaN
# 9502            NaN            NaN         NaN         NaN
# 11828           NaN            NaN         NaN         NaN
# 3632   1965.04.04.a         2671.0         NaN         NaN
# 19513           NaN            NaN         NaN         NaN
# 15695           NaN            NaN         NaN         NaN
# 15780           NaN            NaN         NaN         NaN
# 13000           NaN            NaN         NaN         NaN
# 8343            NaN            NaN         NaN         NaN
# 17215           NaN            NaN         NaN         NaN
# 24263           NaN            NaN         NaN         NaN
#
# [20 rows x 24 columns]

# %%
# Columns with NA values (percentage)
cols_missing_value(df)
# Out:
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %% [markdown]
# ### A few observations
#    - column names contain punctuation, spaces and capitals
#    - case number seems to be same as Date, and Year is a pary of previous two
#    - many rows have no data at all
#    - pdf is part of href formula, which in turn is equal to href
#    - last 2 columns have no name and out of 25723 only 1 or 2 rows have a value
#    - age and species values are mainly missing

# %% [markdown]
# ## General cleanup
#
# Now we know a little about our data set, we are going to start cleaning. First we tackle the big stuff.

# %%
# We clean up th column names, so it's easier to work with.
df.columns = clean_col_names(df)
df.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal_yn', 'time',
#        'species', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number1', 'case_number2', 'original_order', 'unnamed_22',
#        'unnamed_23'],
#       dtype='object')

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
cols_missing_value(df)
# Out:
# case_number                0.031686
# date                       0.158428
# year                       0.190114
# type                       0.221800
# country                    0.950570
# area                       7.366920
# location                   8.713561
# activity                   8.776933
# name                       3.485425
# sex                        9.109632
# age                       45.009506
# injury                     0.602028
# fatal_yn                   8.697719
# time                      53.295311
# species                   45.120406
# investigator_or_source     0.427757
# pdf                        0.158428
# href_formula               0.174271
# href                       0.158428
# case_number1               0.158428
# case_number2               0.158428
# original_order             0.047529
# unnamed_22                99.984157
# unnamed_23                99.968314
# dtype: float64

# %% [markdown]
# ## Clearing redundant columns
#
# Since case_number is same as date, and original_order is a unique index, we will drop all 3 case_number columns. Also, the href_formula and pdf column are duplicate to href. Finally we remove the redundant unnamed columns

# %%
to_drop = ["case_number", "year", "pdf", 
           "href_formula", "case_number1", 
           "case_number2", "unnamed_22", "unnamed_23"]
df = df.drop(axis = 1, columns = to_drop)
df.head()
# Out:
#           date        type    country             area  \
# 0  25-Jun-2018     Boating        USA       California
# 1  18-Jun-2018  Unprovoked        USA          Georgia
# 2  09-Jun-2018         NaN        USA           Hawaii
# 3  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#            species          investigator_or_source  \
# 0      White shark                R. Collier, GSAF
# 1              NaN  K.McMurray, TrackingSharks.com
# 2              NaN  K.McMurray, TrackingSharks.com
# 3        2 m shark                  B. Myatt, GSAF
# 4  Tiger shark, 3m                       A .Kipper
#
#                                                 href  original_order
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6303.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6302.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6301.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6300.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6299.0

# %% [markdown]
# ## Removing bogus rows
#
# When rows hold no real data, we remove them

# %%
# If there is no location we don't want to keep the row
cols_missing_value(df)
# Out:
# date                       0.158428
# type                       8.919518
# country                    0.950570
# area                       7.366920
# location                   8.713561
# activity                   8.776933
# name                       3.485425
# sex                        9.109632
# age                       45.009506
# injury                     0.602028
# fatal_yn                   8.697719
# time                      53.295311
# species                   45.120406
# investigator_or_source     0.427757
# href                       0.158428
# original_order             0.047529
# dtype: float64

# %%
# There are still many rows with very little data. 
# We will drop all that have less than 2 columns of data
df.dropna(thresh=2, inplace=True)
df.dropna(subset=["country"], inplace=True)

# %%
df.sample(30)
# Out:
#                       date        type          country  \
# 1574           25-Jun-2005  Unprovoked              USA
# 2667           03-Sep-1989    Provoked              USA
# 5544  Reported 23-Sep-1901  Unprovoked           CYPRUS
# 5511           04-Feb-1904  Unprovoked      NEW ZEALAND
# 1258           14-May-2008  Unprovoked             FIJI
# 3229           25-Apr-1975         NaN            ITALY
# 4554           25-Jan-1948  Unprovoked        AUSTRALIA
# 1893           07-Nov-2001         NaN        AUSTRALIA
# 1094           01-Sep-2009    Provoked  SOLOMON ISLANDS
# 5128           20-Apr-1927  Unprovoked        AUSTRALIA
# 1689           14-Mar-2004  Unprovoked              USA
# 3299           25-Aug-1973  Unprovoked        AUSTRALIA
# 5863           Before 1878  Unprovoked            INDIA
# 5497           06-Apr-1905  Unprovoked     SOUTH AFRICA
# 5507           28-Jul-1904  Unprovoked              USA
# 2987           28-Feb-1982  Unprovoked        AUSTRALIA
# 5391  Reported 08-Apr-1911     Boating      NEW ZEALAND
# 2021           21-Aug-2000  Unprovoked              USA
# 3328           08-Aug-1972  Unprovoked        AUSTRALIA
# 3020           20-Jul-1981  Unprovoked              USA
# 6079  Reported 19-Aug-1836  Unprovoked          ENGLAND
# 2912           22-Dec-1983  Unprovoked     SOUTH AFRICA
# 5545           30-Jul-1901  Unprovoked     SOUTH AFRICA
# 3136              Dec-1977     Boating     SOUTH AFRICA
# 2784           01-Apr-1987  Unprovoked          VANUATU
# 2382           14-Jun-1995  Unprovoked              USA
# 4608           17-Jan-1946  Unprovoked        AUSTRALIA
# 1772           25-May-2003  Unprovoked              USA
# 3524           13-Jun-1967    Provoked              USA
# 5335  Reported 09-Jul-1914    Provoked              USA
#
#                        area  \
# 1574                Florida
# 2667             California
# 5544        Southern Cyprus
# 5511           North Island
# 1258         Yasawa Islands
# 3229         Genoa Province
# 4554        New South Wales
# 1893      Western Australia
# 1094  Makira-Ulawa Province
# 5128          Torres Strait
# 1689                 Hawaii
# 3299             Queensland
# 5863           Hoogly River
# 5497          KwaZulu-Natal
# 5507             New Jersey
# 2987               Tasmania
# 5391        Chatham Islands
# 2021         North Carolina
# 3328               Tasmania
# 3020                Florida
# 6079             Cumberland
# 2912  Eastern Cape Province
# 5545  Western Cape Province
# 3136  Western Cape Province
# 2784       Malampa Province
# 2382                 Hawaii
# 4608             Queensland
# 1772                Florida
# 3524                Florida
# 5335              Louisiana
#
#                                                location  \
# 1574                              Destin, Walton County
# 2667  24 km off Santa Catalina Island in the Channel...
# 5544                                            Larnaca
# 5511                                            Waitara
# 1258                                      Turtle Island
# 3229                                            Cervara
# 4554                             Mona Vale, near Sydney
# 1893           Leighton Beach, south of North Cottesloe
# 1094   Kirakira, Makira Island (formerly San Cristobal)
# 5128                               Near Thursday Island
# 1689                                            Punaluu
# 3299                   Point Lookout, Stradbroke Island
# 5863                                      Near Calcutta
# 5497                                 Back Beach, Durban
# 5507                 Shrewsbury River,  Monmouth County
# 2987                                     South Cape Bay
# 5391                                                NaN
# 2021         Bouges Bank, Emerald Isle, Carteret County
# 3328                                      Tasman Island
# 3020              St. Petersburg Beach, Pinellas County
# 6079                                         Whitehaven
# 2912                                   Great Fish River
# 5545                                     Windmill Beach
# 3136                                Macassar, False Bay
# 2784                                         Vao Island
# 2382         Opposite Grand Wailea Resort, Wailea, Maui
# 4608                                         Townsville
# 1772  Coral Cove Park, Jupiter Inlet, Palm Beach County
# 3524                            Key West, Monroe County
# 5335                                        New Orleans
#
#                         activity  \
# 1574  Swimming with boogie board
# 2667       Filming 5' blue shark
# 5544                    Swimming
# 5511                    Swimming
# 1258                Night diving
# 3229                Scuba diving
# 4554                 Surf skiing
# 1893                 Surf-skiing
# 1094                     Fishing
# 5128                      Diving
# 1689                  Snorkeling
# 3299                     Surfing
# 5863                         NaN
# 5497                    Swimming
# 5507                     Sailing
# 2987                Spearfishing
# 5391                     Fishing
# 2021  Swimming out to porpoises
# 3328          Diving for abalone
# 3020                    Swimming
# 6079                    Swimming
# 2912                    Swimming
# 5545                    Swimming
# 3136     Fishing for bottom fish
# 2784                    Swimming
# 2382                    Swimming
# 4608                         NaN
# 1772                     Surfing
# 3524                Spearfishing
# 5335                     Fishing
#
#                                                   name  sex   age  \
# 1574                               Jamie Marie Daigle     F    14
# 2667                                      Larry Stroup    M    46
# 5544                                              male    M  Teen
# 5511                                      Ngawai Rakau    M    30
# 1258                                     Aisake Sadole    M    28
# 3229                                    Walter Sansoni    M    37
# 4554                                      David Button    M   NaN
# 1893                                              male    M   NaN
# 1094                                              male    M   NaN
# 5128               Napoleon Doola, a  Murray Islander)    M   NaN
# 1689                                         C. Mooney    F   NaN
# 3299                          Bruce Lawlor (or Lawler)    M    16
# 5863                                            Indian    M   NaN
# 5497                                    James Anderson    M    26
# 5507                                boat, 2  occupants    M   NaN
# 2987                                       Geert Talen    M    32
# 5391                                       2 fishermen  NaN   NaN
# 2021                                              male    M   NaN
# 3328                                    Gordon Johnson    M    45
# 3020                                       Lisa Drenko    F    16
# 6079                                             a boy    M   NaN
# 2912                                       Colin Biggs    M    16
# 5545  John Hendrick Adrian Chandler, a prisoner of war    M    29
# 3136                    boat, occupant: Danie Schoeman  NaN   NaN
# 2784                                              male    M     8
# 2382                                      Donald Bloom    M    38
# 4608                                    Donald Vaughan    M    12
# 1772                            Kris "Cutty" Kildosher    M    18
# 3524                            Andres Puma (or Pruna)    M    26
# 5335                                             Lopez    M   NaN
#
#                                                  injury fatal_yn   time  \
# 1574                                  FATAL, leg bitten        Y  11h15
# 2667       Hand  & both arms bitten   PROVOKED INCIDENT        N    NaN
# 5544                FATAL, bitten on arms, chest & legs        Y    NaN
# 5511                                              FATAL        Y    NaN
# 1258                                              FATAL        Y  Night
# 3229  The press reported this as an attack by a whit...      NaN    NaN
# 4554                              No injury, ski bitten        N    NaN
# 1893  No injury, fell off ski after possibly collidi...      NaN    NaN
# 1094          Injuries to face & neck PROVOKED INCIDENT        N    NaN
# 5128                     Extensive injuries to left leg        N    NaN
# 1689                           Lacerations to left foot        N  10h00
# 3299                                 Right foot severed        N    NaN
# 5863     Thigh severely bitten, femur exposed & grooved        N    NaN
# 5497      FATAL, thigh bitten, femoral artery severed          Y  16h30
# 5507                                          No injury        N    NaN
# 2987                          FATAL, body not recovered        Y    NaN
# 5391             No injury to occupants, shark bit boat        N    NaN
# 2021  Severe gash to left hand above wrist, almost s...        N    NaN
# 3328                                   Left foot bitten        N    NaN
# 3020  Foot bitten between arch & big toe, no stitche...        N    NaN
# 6079                                              FATAL        Y    NaN
# 2912                  Left calf, ankle & foot lacerated        N  12h30
# 5545  Right leg bitten & foot severed, right arm bit...        Y  14h15
# 3136  No injury to occupant: shark bit boat's port c...        N    NaN
# 2784                                              FATAL        Y  12h00
# 2382   Puncture wounds & scratches to torso & left leg         N  11h50
# 4608                                       Ankle bitten        N    NaN
# 1772                                Left foot lacerated        N  10h00
# 3524  After shark was speared & hit on head, it bit ...        N  17h30
# 5335  PROVOKED INCIDENT    Legs severed by shark ent...        N    NaN
#
#                                                 species  \
# 1574                              1.8 m [6'] bull shark
# 2667                                        Blue Shark
# 5544                                          2 m shark
# 5511                                                NaN
# 1258                                                NaN
# 3229                                            Invalid
# 4554                                           6' shark
# 1893                                                NaN
# 1094                                                NaN
# 5128                                                NaN
# 1689                                   1.8 m [6'] shark
# 3299                                          12' shark
# 5863                                                NaN
# 5497                                                NaN
# 5507                                                NaN
# 2987                           5.5 m [18''] white shark
# 5391                                                NaN
# 2021                                                NaN
# 3328                                   White shark, 10'
# 3020                                        "sandshark"
# 6079                                                NaN
# 2912                                                NaN
# 5545                                        White shark
# 3136  3 m [10'] white shark (Tooth  recovered from b...
# 2784                                        4.3 m shark
# 2382                          Tiger shark, 3.7 m [12']
# 4608                                        small shark
# 1772                                                NaN
# 3524                                  Nurse shark, 1 m
# 5335                                                NaN
#
#                                  investigator_or_source  \
# 1574                                    E. Ritter, GSAF
# 2667  R. Collier, p. xxvi;  Orlando Sentinel, 9/6/19...
# 5544                  Bardanis citing Embros, 9/23/1901
# 5511                                     Star, 2/4/1904
# 1258                              Fiji Times, 5/15/2008
# 3229                                     C. Moore, GSAF
# 4554                             Cairns Post, 1/27/1948
# 1893                                     T. Peake, GSAF
# 1094                             Solomon Star, 9/4/2009
# 5128  J. Green, p.32; Bartlett, p. 160; V.M. Copples...
# 1689    Hawaii Department of Land and Natural Resources
# 3299  L.A. Times, 8/16/1973, p.B4; R. McKenzie, Sund...
# 5863  J. Fayrer, M.D. cited in F. Day, The Fishes of...
# 5497  Natal Mercury, 4/7/1905; H.Gill & M. Levine, GSAF
# 5507                 New York Herald Tribune, 7/29/1904
# 2987                              C. Black, pp. 159-163
# 5391                         Grey River Argus, 4/8/1911
# 2021  C. Creswell, GSAF; Wilmington Morning Star; Ch...
# 3328  The Age, 8/10/1972; J. Green, p.36; C. Black, ...
# 3020                                      E. Pace, GSAF
# 6079                                     C. Moore, GSAF
# 2912  C. Biggs, M. Levine, J. Mansfield, Dr. T. Coun...
# 5545                                    M. Levine, GSAF
# 3136                                   T. Wallett, p.38
# 2784                                           S. Combs
# 2382                               G. Ambrose, pp.41-47
# 4608  G.P. Whitley (1951), p.193; V.M. Coppleson (19...
# 1772                                       Local 6 News
# 3524          H.D. Baldridge, p.192; M. McDiarmid, p.70
# 5335                          Lima Daily News, 7/9/1914
#
#                                                    href  original_order
# 1574  http://sharkattackfile.net/spreadsheets/pdf_di...          4729.0
# 2667  http://sharkattackfile.net/spreadsheets/pdf_di...          3636.0
# 5544  http://sharkattackfile.net/spreadsheets/pdf_di...           759.0
# 5511  http://sharkattackfile.net/spreadsheets/pdf_di...           792.0
# 1258  http://sharkattackfile.net/spreadsheets/pdf_di...          5045.0
# 3229  http://sharkattackfile.net/spreadsheets/pdf_di...          3074.0
# 4554  http://sharkattackfile.net/spreadsheets/pdf_di...          1749.0
# 1893  http://sharkattackfile.net/spreadsheets/pdf_di...          4410.0
# 1094  http://sharkattackfile.net/spreadsheets/pdf_di...          5209.0
# 5128  http://sharkattackfile.net/spreadsheets/pdf_di...          1175.0
# 1689  http://sharkattackfile.net/spreadsheets/pdf_di...          4614.0
# 3299  http://sharkattackfile.net/spreadsheets/pdf_di...          3004.0
# 5863  http://sharkattackfile.net/spreadsheets/pdf_di...           440.0
# 5497  http://sharkattackfile.net/spreadsheets/pdf_di...           806.0
# 5507  http://sharkattackfile.net/spreadsheets/pdf_di...           796.0
# 2987  http://sharkattackfile.net/spreadsheets/pdf_di...          3316.0
# 5391  http://sharkattackfile.net/spreadsheets/pdf_di...           912.0
# 2021  http://sharkattackfile.net/spreadsheets/pdf_di...          4282.0
# 3328  http://sharkattackfile.net/spreadsheets/pdf_di...          2975.0
# 3020  http://sharkattackfile.net/spreadsheets/pdf_di...          3283.0
# 6079  http://sharkattackfile.net/spreadsheets/pdf_di...           224.0
# 2912  http://sharkattackfile.net/spreadsheets/pdf_di...          3391.0
# 5545  http://sharkattackfile.net/spreadsheets/pdf_di...           758.0
# 3136  http://sharkattackfile.net/spreadsheets/pdf_di...          3167.0
# 2784  http://sharkattackfile.net/spreadsheets/pdf_di...          3519.0
# 2382  http://sharkattackfile.net/spreadsheets/pdf_di...          3921.0
# 4608  http://sharkattackfile.net/spreadsheets/pdf_di...          1695.0
# 1772  http://sharkattackfile.net/spreadsheets/pdf_di...          4531.0
# 3524  http://sharkattackfile.net/spreadsheets/pdf_di...          2779.0
# 5335  http://sharkattackfile.net/spreadsheets/pdf_di...           968.0

# %% [markdown]
# ## Type
#
# We start cleaning more in depth by looking at the type column.

# %%
# We check the values for 'type'
df["type"].value_counts(dropna=False)
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# NaN               14
# Questionable       2
# Boatomg            1
# Name: type, dtype: int64

# %%
# Change invalid and questionable to NaN
df["type"].replace(["Invalid", "Questionable"], np.nan, inplace=True)

# And merge boating
df["type"].replace(["Boat", "Boatomg"], "Boating", inplace=True)

df["type"].value_counts(dropna=False)
# Out:
# Unprovoked      4595
# Provoked         574
# NaN              563
# Boating          341
# Sea Disaster     239
# Name: type, dtype: int64

# %% [markdown]
# ## Date
# Next we look at the date.

# %%
# Change date to datetime column
df.date = pd.to_datetime(df["date"], errors="coerce", )
df.head()
# Out:
#         date        type    country             area  \
# 0 2018-06-25     Boating        USA       California
# 1 2018-06-18  Unprovoked        USA          Georgia
# 2 2018-06-09         NaN        USA           Hawaii
# 3 2018-06-08  Unprovoked  AUSTRALIA  New South Wales
# 4 2018-06-04    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#            species          investigator_or_source  \
# 0      White shark                R. Collier, GSAF
# 1              NaN  K.McMurray, TrackingSharks.com
# 2              NaN  K.McMurray, TrackingSharks.com
# 3        2 m shark                  B. Myatt, GSAF
# 4  Tiger shark, 3m                       A .Kipper
#
#                                                 href  original_order
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6303.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6302.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6301.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6300.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6299.0

# %%
# Get rid of future dates. Doesn't work because of 20 rows that aren't yet in date format it seems.
#df["date"] = df["date"].apply(invalid_year)
df.date.isna().values.sum()
# Out:
# 821

# %% [markdown]
# ## Activity column
# This column takes a lot more work. There are many different values, more than 1500. We will try to use combine them to bring it down to 120.

# %%
df["activity"].value_counts()
# Out:
# Surfing                                                      970
# Swimming                                                     862
# Fishing                                                      431
# Spearfishing                                                 332
# Bathing                                                      160
#                                                             ...
# Competing in spearfishing championship & towing dead fish      1
# American schooner Orator capsized                              1
# Free diving for abalone (surfacing)                            1
# Standing, gathering oysters                                    1
# Gigging for flounder                                           1
# Name: activity, Length: 1513, dtype: int64

# %%
# Let's check what values we have in this column
df["activity"].unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
# Key is category, list in dict-value are search patterns
regex_dict = {"shipwreck": ["wreck", "sea disaster", "battle", 
                            "sunk", "sank", "capsiz", "swamped",
                            "burning", "Fell", "adrift", "washed",
                            "overboard", "thrown", "sink", "swept",
                            "murder", "explosion", "freighter", "tanker",
                            "founder", "steam", "submarine", "torped",
                            "destroy", "collided", "drown", "desert",
                            "accident", "disappear", "dinghy", "raft"],
              "beach activity": [r"sta.*ding", "wading", "walking", 
                                 "gathering", "lying", "splash", "playing",
                                 "wading", "inflat", "sitting"],
              "shark handling": ["shark"],
              "surfing": ["surfboard", r"surf[a-z]?ng", "kite", r"sup\b", 
                          "boardi", "paddling"],
              "aircrash": ["airc", "air disaster", "air/sea disaster", 
                           "airlin", r"air.*force", "plane", "boeing"], 
              "canoeing": [r".*skiing", "canoe", "kayak"],
              "fishing": [r"fish[a-z]*", "hunting", "spear", "netting", "prawn",
                          "harpoo", "lobster", "crab", "collecting", "shrimp",
                          "oyster", "sardine", "hauling", "casting", "catching"],
              "washing": [r"wash[^e]"],
              "swimming": ["swimming", "treading", "dived", r"swim", 
                           "bathing", "floating", "jump", "kneeling"],
              "boating": ["boating", "sailing", "rowing", "cruising", "yacht"],
              "diving": ["diving", "snorkeling", "diver"],
              "research": ["photo", "film", "research", "scient"],
              np.NaN: ["unknown"]}

for k, v in regex_dict.items():
    search_and_set(df, "activity", k, regex=True, lst=v)

# %%
# Check the result
df["activity"].nunique()
# Out:
# 122

# %% [markdown]
# ## Sex column
# This column is fairly straight forward. We can combine into M or F

# %%
# What unique values we have at first
df["sex"].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
# Anything that's not F or M will be set to NaN
search_and_set(df, "sex", np.NaN, lst=[r"[^FM]"])
df["sex"].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %% [markdown]
# ## Name column
# We follow a similar process, but need to account for the fact that some names feature a '.' or ','.

# %%
df["name"].value_counts()
# Out:
# male                 542
# female                97
# boy                   23
# 2 males               14
# boat                  14
#                     ...
# Adolphe Bollander      1
# Markus Groh            1
# Nan-Tien Chang         1
# Johnny Stoch           1
# Kevin Hannecart        1
# Name: name, Length: 5196, dtype: int64

# %%
# First change how Jr is written, so we can check for punctuation later
regex_pat = re.compile(r"[,]* jr[.]*")
df["name"] = (df["name"]
              .str.lower()
              .str.strip()
              .str.replace(regex_pat, " jr", regex=True))

# Now remove everything with punctuation
search_and_set(df, "name", np.NaN, regex=True, 
               lst=[r"\d", r"\ba\s[a-z]*", "male", r"[,:;]"])

# And remove all single 'names'
df["name"] = df["name"].str.title().apply(regex_test, args=(r"[ ]", ))

# %% [markdown]
# ## Age
# For age we decide only to keep values that are 1 or 2 digits. As well we change the dtype to int.

# %%
# Next we clean up the age column
df.age.value_counts()
# Out:
# 17          154
# 18          150
# 19          142
# 15          139
# 20          139
#            ...
# 60s           1
# 16 to 18      1
# mid-20s       1
# 34 & 19       1
# 87            1
# Name: age, Length: 157, dtype: int64

# %%
# First correct for babies
search_and_set(df, "age", "1", lst=["month"])
# Now if we find 1 or 2 digits we keep that value. 
df["age"] = df["age"].str.strip().apply(regex_test, args=(r"\d{1,2}", True))

# %%
# Now we've cleared bogus values, we can convert to integer
df["age"] = df["age"].fillna(0).astype(int)

# %% [markdown]
# ## Fatal_yn
# This column is fairly straight forward, and we can just use the method we used earlier as well.

# %%
df.fatal_yn.unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
regex_dict = {np.NaN: ["unknown", "2017"],
         "N": ["n", "m"],
         "Y": ["y"]
        }
for k,v in regex_dict.items():
    search_and_set(df, "fatal_yn", k, regex=True, lst=v)

# %% [markdown]
# ## Setting a new index
#
# If original_order is unique then we can use it as an index

# %%
df["original_order"].value_counts(dropna=False)
# Out:
# 569.0     2
# 3854.0    1
# 725.0     1
# 708.0     1
# 590.0     1
#          ..
# 3106.0    1
# 3080.0    1
# 2812.0    1
# 2712.0    1
# 6272.0    1
# Name: original_order, Length: 6251, dtype: int64

# %%
# There are 2 rows with number 569. The highest value is 6303, so we change one of the 2 to 6304.

df.loc[(df["original_order"] == 569) & (df["type"] == "Unprovoked"), "original_order"] = 6304

# %%
# Getting rid of empty rows
df["original_order"].dropna(inplace=True)

# %%
# We change the column dtype to int
df["original_order"] = df["original_order"].astype(int)

# %%
# Now the original_order is unique, we can use it as an index
df.set_index("original_order", inplace=True)
df.head()
# Out:
#                      date        type    country             area  \
# original_order
# 6303           2018-06-25     Boating        USA       California
# 6302           2018-06-18  Unprovoked        USA          Georgia
# 6301           2018-06-09         NaN        USA           Hawaii
# 6300           2018-06-08  Unprovoked  AUSTRALIA  New South Wales
# 6299           2018-06-04    Provoked     MEXICO           Colima
#
#                                       location        activity           name  \
# original_order
# 6303               Oceanside, San Diego County         surfing    Julie Wolfe
# 6302            St. Simon Island, Glynn County  beach activity            NaN
# 6301                              Habush, Oahu         surfing    John Denges
# 6300                        Arrawarra Headland         surfing            NaN
# 6299                                  La Ticla          diving  Gustavo Ramos
#
#                sex  age                                             injury  \
# original_order
# 6303             F   57  No injury to occupant, outrigger canoe and pad...
# 6302             F   11                         Minor injury to left thigh
# 6301             M   48       Injury to left lower leg from surfboard skeg
# 6300             M    0                          Minor injury to lower leg
# 6299             M    0  Lacerations to leg & hand shark PROVOKED INCIDENT
#
#                fatal_yn           time          species  \
# original_order
# 6303                  N          18h00      White shark
# 6302                  N  14h00  -15h00              NaN
# 6301                  N          07h45              NaN
# 6300                  N            NaN        2 m shark
# 6299                  N            NaN  Tiger shark, 3m
#
#                         investigator_or_source  \
# original_order
# 6303                          R. Collier, GSAF
# 6302            K.McMurray, TrackingSharks.com
# 6301            K.McMurray, TrackingSharks.com
# 6300                            B. Myatt, GSAF
# 6299                                 A .Kipper
#
#                                                              href
# original_order
# 6303            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6302            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299            http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# ## Export
# Now that the dataset is a lot cleaner, we will save it as a new csv-file.

# %%
df.to_csv("cleaned_sharks.csv")
