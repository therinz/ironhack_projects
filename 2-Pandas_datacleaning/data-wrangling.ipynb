# %% [markdown]
# # Pandas Project - cleaning shark attacks csv

# %% [markdown]
# ## Workflow determination
# 1. Determine steps to be taken
# 2. Set up csv in pandas and create copy to work with
# 3. Declare helper functions
# 3. Gather information about shape and characteristics of dataframe
# 6. Check data types
# 4. Inspect data
# 9. Check null values
# 5. Change column names
# 8. Remove duplicates
# 10. Remove irrelevant columns
# 11. Convert dates
# 12. Clean data for various columns
# 12. Correct data types
# 14. Set new index according to unique tracker
# 15. Export to new csv

# %% [markdown]
# ## Set up
#
#
# First we import the necessary libraries

# %%
import re

import numpy as np
import pandas as pd

from string import punctuation
from datetime import datetime

# %% [markdown]
# Now we declare helper functions

# %%
def clean_col_names(df):
    """Take a dataframe and return sanitized column names."""

    table = str.maketrans(dict.fromkeys(punctuation))
    return [c.lower()
             .strip()
             .translate(table)
             .replace(" ", "_") for c in df.columns]


def cols_missing_value(df):
    """Return percentage of column missing value."""
    
    return ((df.isna().sum())[df.isna().sum() > 0] / len(df)) * 100

def invalid_year(date):
    """Return NaT if not valid year."""
    
    # Doesn't work because of 20 non-cooperating rows
    if date == date:
        if date > datetime.strptime('2020', '%y'):
            return pd.NaT
    return date

def search_and_set(df, col, word, regex=False, lst=[]):
    """Search for term and set correspending rows to value."""
    
    # If lst is set, we use every term therein, otherwise just 
    # set word as first item
        
    if not lst:
        lst = [word]
    
    if regex:
        for item in lst:
            df.loc[df[col].str.contains(
                item, case=False, na=False, regex=True), col] = word
    else:
        for item in lst:
            df.loc[df[col].str.contains(
                item, case=False, na=False), col] = word

def regex_test(txt, pat, needle=False):
    """Return NaN if string does not contain pattern."""
    
    check = re.search(pat, str(txt))
    if check:
        # With needle set to True we return the part of matched string
        return check.group() if needle else txt
    return np.NaN

# %% [markdown]
# Next we import the csv into pandas and inspect the head

# %%
# Because of unicode characters we need to specify the encoding
df_original = pd.read_csv("attacks.csv", encoding="cp1252")

# We save a copy of the dataframe, just in case.
df = df_original.copy()
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Inspect

# %%
# rows and columns
df.shape
# Out:
# (25723, 24)

# %%
# Datatypes of columns
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
# Random sample of data
df.sample(20)
# Out:
#         Case Number         Date    Year        Type       Country  \
# 13858           NaN          NaN     NaN         NaN           NaN
# 11883           NaN          NaN     NaN         NaN           NaN
# 3311   1973.00.00.a         1973  1973.0  Unprovoked  SOUTH AFRICA
# 24178           NaN          NaN     NaN         NaN           NaN
# 12811           NaN          NaN     NaN         NaN           NaN
# 16416           NaN          NaN     NaN         NaN           NaN
# 20781           NaN          NaN     NaN         NaN           NaN
# 6438              0          NaN     NaN         NaN           NaN
# 23994           NaN          NaN     NaN         NaN           NaN
# 13085           NaN          NaN     NaN         NaN           NaN
# 20441           NaN          NaN     NaN         NaN           NaN
# 11087           NaN          NaN     NaN         NaN           NaN
# 19793           NaN          NaN     NaN         NaN           NaN
# 24382           NaN          NaN     NaN         NaN           NaN
# 17055           NaN          NaN     NaN         NaN           NaN
# 20712           NaN          NaN     NaN         NaN           NaN
# 6918              0          NaN     NaN         NaN           NaN
# 13685           NaN          NaN     NaN         NaN           NaN
# 16421           NaN          NaN     NaN         NaN           NaN
# 3051     1980.11.18  18-Nov-1980  1980.0  Unprovoked     AUSTRALIA
#
#                         Area         Location  Activity  \
# 13858                    NaN              NaN       NaN
# 11883                    NaN              NaN       NaN
# 3311   Eastern Cape Province  Queensberry Bay   Surfing
# 24178                    NaN              NaN       NaN
# 12811                    NaN              NaN       NaN
# 16416                    NaN              NaN       NaN
# 20781                    NaN              NaN       NaN
# 6438                     NaN              NaN       NaN
# 23994                    NaN              NaN       NaN
# 13085                    NaN              NaN       NaN
# 20441                    NaN              NaN       NaN
# 11087                    NaN              NaN       NaN
# 19793                    NaN              NaN       NaN
# 24382                    NaN              NaN       NaN
# 17055                    NaN              NaN       NaN
# 20712                    NaN              NaN       NaN
# 6918                     NaN              NaN       NaN
# 13685                    NaN              NaN       NaN
# 16421                    NaN              NaN       NaN
# 3051       Western Australia         Lancelin  Swimming
#
#                                                     Name Sex   ... Species   \
# 13858                                                NaN  NaN  ...      NaN
# 11883                                                NaN  NaN  ...      NaN
# 3311                                       Gordon Harmer    M  ...      NaN
# 24178                                                NaN  NaN  ...      NaN
# 12811                                                NaN  NaN  ...      NaN
# 16416                                                NaN  NaN  ...      NaN
# 20781                                                NaN  NaN  ...      NaN
# 6438                                                 NaN  NaN  ...      NaN
# 23994                                                NaN  NaN  ...      NaN
# 13085                                                NaN  NaN  ...      NaN
# 20441                                                NaN  NaN  ...      NaN
# 11087                                                NaN  NaN  ...      NaN
# 19793                                                NaN  NaN  ...      NaN
# 24382                                                NaN  NaN  ...      NaN
# 17055                                                NaN  NaN  ...      NaN
# 20712                                                NaN  NaN  ...      NaN
# 6918                                                 NaN  NaN  ...      NaN
# 13685                                                NaN  NaN  ...      NaN
# 16421                                                NaN  NaN  ...      NaN
# 3051   G.R. Bohan, an Able Seaman stationed on HMAS S...    M  ...      NaN
#
#       Investigator or Source                      pdf  \
# 13858                    NaN                      NaN
# 11883                    NaN                      NaN
# 3311               G. Harmer  1973.00.00.a-Harmer.pdf
# 24178                    NaN                      NaN
# 12811                    NaN                      NaN
# 16416                    NaN                      NaN
# 20781                    NaN                      NaN
# 6438                     NaN                      NaN
# 23994                    NaN                      NaN
# 13085                    NaN                      NaN
# 20441                    NaN                      NaN
# 11087                    NaN                      NaN
# 19793                    NaN                      NaN
# 24382                    NaN                      NaN
# 17055                    NaN                      NaN
# 20712                    NaN                      NaN
# 6918                     NaN                      NaN
# 13685                    NaN                      NaN
# 16421                    NaN                      NaN
# 3051   A. Sharpe, pp.133-134     1980.11.18-Bohan.pdf
#
#                                             href formula  \
# 13858                                                NaN
# 11883                                                NaN
# 3311   http://sharkattackfile.net/spreadsheets/pdf_di...
# 24178                                                NaN
# 12811                                                NaN
# 16416                                                NaN
# 20781                                                NaN
# 6438                                                 NaN
# 23994                                                NaN
# 13085                                                NaN
# 20441                                                NaN
# 11087                                                NaN
# 19793                                                NaN
# 24382                                                NaN
# 17055                                                NaN
# 20712                                                NaN
# 6918                                                 NaN
# 13685                                                NaN
# 16421                                                NaN
# 3051   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                     href Case Number.1  \
# 13858                                                NaN           NaN
# 11883                                                NaN           NaN
# 3311   http://sharkattackfile.net/spreadsheets/pdf_di...  1973.00.00.a
# 24178                                                NaN           NaN
# 12811                                                NaN           NaN
# 16416                                                NaN           NaN
# 20781                                                NaN           NaN
# 6438                                                 NaN           NaN
# 23994                                                NaN           NaN
# 13085                                                NaN           NaN
# 20441                                                NaN           NaN
# 11087                                                NaN           NaN
# 19793                                                NaN           NaN
# 24382                                                NaN           NaN
# 17055                                                NaN           NaN
# 20712                                                NaN           NaN
# 6918                                                 NaN           NaN
# 13685                                                NaN           NaN
# 16421                                                NaN           NaN
# 3051   http://sharkattackfile.net/spreadsheets/pdf_di...    1980.11.18
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 13858           NaN            NaN         NaN         NaN
# 11883           NaN            NaN         NaN         NaN
# 3311   1973.00.00.a         2992.0         NaN         NaN
# 24178           NaN            NaN         NaN         NaN
# 12811           NaN            NaN         NaN         NaN
# 16416           NaN            NaN         NaN         NaN
# 20781           NaN            NaN         NaN         NaN
# 6438            NaN            NaN         NaN         NaN
# 23994           NaN            NaN         NaN         NaN
# 13085           NaN            NaN         NaN         NaN
# 20441           NaN            NaN         NaN         NaN
# 11087           NaN            NaN         NaN         NaN
# 19793           NaN            NaN         NaN         NaN
# 24382           NaN            NaN         NaN         NaN
# 17055           NaN            NaN         NaN         NaN
# 20712           NaN            NaN         NaN         NaN
# 6918            NaN            NaN         NaN         NaN
# 13685           NaN            NaN         NaN         NaN
# 16421           NaN            NaN         NaN         NaN
# 3051     1980.11.18         3252.0         NaN         NaN
#
# [20 rows x 24 columns]

# %%
# Columns with NA values (percentage)
cols_missing_value(df)
# Out:
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %% [markdown]
# ### A few observations
#    - column names contain punctuation, spaces and capitals
#    - case number seems to be same as Date, and Year is a pary of previous two
#    - many rows have no data at all
#    - pdf is part of href formula, which in turn is equal to href
#    - last 2 columns have no name and out of 25723 only 1 or 2 rows have a value
#    - age and species values are mainly missing

# %% [markdown]
# ## General cleanup
#
# Now we know a little about our data set, we are going to start cleaning. First we tackle the big stuff.

# %%
# We clean up th column names, so it's easier to work with.
df.columns = clean_col_names(df)
df.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal_yn', 'time',
#        'species', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number1', 'case_number2', 'original_order', 'unnamed_22',
#        'unnamed_23'],
#       dtype='object')

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
cols_missing_value(df)
# Out:
# case_number                0.031686
# date                       0.158428
# year                       0.190114
# type                       0.221800
# country                    0.950570
# area                       7.366920
# location                   8.713561
# activity                   8.776933
# name                       3.485425
# sex                        9.109632
# age                       45.009506
# injury                     0.602028
# fatal_yn                   8.697719
# time                      53.295311
# species                   45.120406
# investigator_or_source     0.427757
# pdf                        0.158428
# href_formula               0.174271
# href                       0.158428
# case_number1               0.158428
# case_number2               0.158428
# original_order             0.047529
# unnamed_22                99.984157
# unnamed_23                99.968314
# dtype: float64

# %% [markdown]
# ## Clearing redundant columns
#
# Since case_number is same as date, and original_order is a unique index, we will drop all 3 case_number columns. Also, the href_formula and pdf column are duplicate to href. Finally we remove the redundant unnamed columns

# %%
to_drop = ["case_number", "year", "pdf", 
           "href_formula", "case_number1", 
           "case_number2", "unnamed_22", "unnamed_23"]
df = df.drop(axis = 1, columns = to_drop)
df.head()
# Out:
#           date        type    country             area  \
# 0  25-Jun-2018     Boating        USA       California
# 1  18-Jun-2018  Unprovoked        USA          Georgia
# 2  09-Jun-2018     Invalid        USA           Hawaii
# 3  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#            species          investigator_or_source  \
# 0      White shark                R. Collier, GSAF
# 1              NaN  K.McMurray, TrackingSharks.com
# 2              NaN  K.McMurray, TrackingSharks.com
# 3        2 m shark                  B. Myatt, GSAF
# 4  Tiger shark, 3m                       A .Kipper
#
#                                                 href  original_order
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6303.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6302.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6301.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6300.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6299.0

# %% [markdown]
# ## Removing bogus rows
#
# When rows hold no real data, we remove them

# %%
# If there is no location we don't want to keep the row
cols_missing_value(df)
# Out:
# date                       0.158428
# type                       0.221800
# country                    0.950570
# area                       7.366920
# location                   8.713561
# activity                   8.776933
# name                       3.485425
# sex                        9.109632
# age                       45.009506
# injury                     0.602028
# fatal_yn                   8.697719
# time                      53.295311
# species                   45.120406
# investigator_or_source     0.427757
# href                       0.158428
# original_order             0.047529
# dtype: float64

# %%
# There are still many rows with very little data. 
# We will drop all that have less than 2 columns of data
df.dropna(thresh=2, inplace=True)
df.dropna(subset=["country"], inplace=True)

# %%
df.sample(30)
# Out:
#                       date          type           country  \
# 6048           08-Dec-1846  Sea Disaster            MEXICO
# 4057           30-Sep-1959    Unprovoked       PHILIPPINES
# 191            24-Dec-2016    Unprovoked         AUSTRALIA
# 5731  Reported 18-Jun-1888       Invalid         AUSTRALIA
# 1129           06-Mar-2009      Provoked           BAHAMAS
# 4522             1949-1950       Boating             ITALY
# 5189           08-Feb-1924       Invalid         AUSTRALIA
# 2472           16-Sep-1993    Unprovoked       EL SALVADOR
# 4590  Reported 24-Dec-1946       Boating         AUSTRALIA
# 1186           06-Dec-2006       Boating         AUSTRALIA
# 2433           31-May-1994    Unprovoked               USA
# 1638           20-Sep-2004    Unprovoked               USA
# 748            02-Sep-2012    Unprovoked               USA
# 2229           24-Aug-1997    Unprovoked               USA
# 3856           06-Jan-1962          Boat      SOUTH AFRICA
# 3872           09-Oct-1961       Invalid               USA
# 3246                  1975    Unprovoked           REUNION
# 2347           31-Aug-1995    Unprovoked               USA
# 3690           05-Mar-1964    Unprovoked               USA
# 959            11-Dec-2010    Unprovoked               USA
# 3620           09-Jun-1965    Unprovoked            MEXICO
# 126            21-Jun-2017    Unprovoked               USA
# 4916           13-Mar-1935      Provoked         AUSTRALIA
# 3346                  1972    Unprovoked  MARSHALL ISLANDS
# 5203           06-Jun-1923       Boating            MEXICO
# 4808           05-Oct-1938      Provoked         AUSTRALIA
# 2720           11-Aug-1988    Unprovoked               USA
# 3107                  1979    Unprovoked               USA
# 4044           28-Nov-1959    Unprovoked         AUSTRALIA
# 3734           04-Nov-1963    Unprovoked             PALAU
#
#                           area  \
# 6048                  Veracruz
# 4057              Leyte Island
# 191          Western Australia
# 5731                  Victoria
# 1129             Exuma Islands
# 4522            Tyrrhenian Sea
# 5189                Queensland
# 2472               La Libertad
# 4590                Queensland
# 1186           New South Wales
# 2433                   Florida
# 1638                    Oregon
# 748                    Florida
# 2229                California
# 3856     Western Cape Province
# 3872                   Florida
# 3246                       NaN
# 2347                   Florida
# 3690                   Florida
# 959                     Hawaii
# 3620                  Veracruz
# 126             South Carolina
# 4916                Queensland
# 3346           Illeginni Atoll
# 5203                 Vera Cruz
# 4808                Queensland
# 2720                California
# 3107                    Hawaii
# 4044                Queensland
# 3734  Western Caroline Islands
#
#                                                location  \
# 6048                                          Vera Cruz
# 4057                                        Luang Dulag
# 191                    Bundegi Sanctuary Zone, Ningaloo
# 5731                       Point Cook, Port Phillip Bay
# 1129                                                NaN
# 4522                                       San Vincenzo
# 5189                                          Currumbin
# 2472                                near El Cocal Beach
# 4590                          Auckland Creek, Gladstone
# 1186                                      Mowarry Point
# 2433                        Ponce Inlet, Volusia County
# 1638                                        Gold  Beach
# 748                    New Smyrna Beach, Volusia County
# 2229           Clam Beach, near Eureka, Humboldt County
# 3856                          6 km off Groot Brak River
# 3872         Ocean Ridge, Boca Raton, Palm Beach County
# 3246                                                NaN
# 2347                North Beach Inlet, St. Lucie County
# 3690                    Fort Lauderdale, Broward County
# 959                                   Tavares Bay, Maui
# 3620                                            Mocambo
# 126   South Forest Beach, Hilton Head Island, Beaufo...
# 4916                                      Pimpana River
# 3346                                                NaN
# 5203                           Outside Vera Cruz Harbor
# 4808                 Between Wynnum & St. Helena Island
# 2720                    Klamath River, Del Norte County
# 3107                              South Kohala, Hawai'i
# 4044                      North Burleigh, near Brisbane
# 3734                                              Koror
#
#                                                activity  \
# 6048                            Wreck of the USS Somers
# 4057                                          Swimming
# 191                                          Snorkeling
# 5731                   The cutter yacht Cutty Sark sank
# 1129                                       Spearfishing
# 4522                                 Fishing, on a boat
# 5189                                            Bathing
# 2472                                            Surfing
# 4590                                                NaN
# 1186                                            Fishing
# 2433                                            Surfing
# 1638                                            Surfing
# 748                         Swimming or boogie boarding
# 2229                     Surfing (sitting on his board)
# 3856                                            Fishing
# 3872                                           Swimming
# 3246                                                NaN
# 2347                                            Surfing
# 3690                                       Skin diving
# 959                                             Surfing
# 3620                                           Swimming
# 126                                            Swimming
# 4916                    Hauling in net with shark in it
# 3346                     Free diving, collecting shells
# 5203  Dismantling cable buoys of the cable ship All ...
# 4808                                            Fishing
# 2720                                            Surfing
# 3107                                            Fishing
# 4044                       Standing in chest-deep water
# 3734                                            Fishing
#
#                                                    name  sex  age  \
# 6048                                                NaN    M  NaN
# 4057                                 Francisco Daguinot    M   28
# 191                                              female    F  NaN
# 5731  Claude Hadley, William Grundy, Albert Faulkner...    M  NaN
# 1129                                     Luis Hernandez    M   48
# 4522                                               male    M  NaN
# 5189                                  Frederick Dullroy    M  NaN
# 2472                                  Jose Diter Roque   NaN   15
# 4590                Moored fishing launch of Harry Lone  NaN  NaN
# 1186  6 m Seaduce - Occupants: Allen Roberts, Jason ...  NaN  NaN
# 2433                                       Steve Polack    M   24
# 1638                                          Seth Mead    M   26
# 748                                              female    F   56
# 2229                                        Scott Yerby    M   29
# 3856  4.8 m  boat Peggy, occupants: John Oktober, L....  NaN  NaN
# 3872                                        Alfred Haen    M   45
# 3246                                          a soldier    M  NaN
# 2347                                      Jason Cablish    M   19
# 3690                                    James R. Duryea    M   38
# 959                                       Andrew Wilson    M   46
# 3620   Father Miguel de Jesus Chavez, a Catholic priest    M   38
# 126                                   Olivia Wallhauser    F   16
# 4916                              William Charles Beitz    M   38
# 3346                                     Alan Titchenal    M  NaN
# 5203     boat, occupants; Carl Sjoistrom & 2 other crew  NaN  NaN
# 4808                                         Jack Lopez    M   18
# 2720                                       Carl Lafazio    M   27
# 3107                                       elderly male    M  NaN
# 4044                                       David Beaver    M   17
# 3734                                      Saburo Dooley    M   35
#
#                                                  injury fatal_yn       time  \
# 6048                   FATAL, some were taken by sharks        Y        NaN
# 4057                               No details, survived        N        NaN
# 191                                      Buttock bitten        N    Morning
# 5731                     Probable drowning & scavenging      NaN        NaN
# 1129  Lacerations to right forearm after he poked th...        N        NaN
# 4522                              No injury to occupant        N        NaN
# 5189                     Probable drowning & scavenging      NaN      16h00
# 2472                                    Left leg gashed        N        NaN
# 4590                          Shark jumped into cockpit        N        NaN
# 1186                         Shark bit boats sea anchor        N    Morning
# 2433                                     Foot lacerated        N      10h30
# 1638                                         Leg bitten        N      09h00
# 748                        Puncture wound to left ankle        N      16h30
# 2229                                  Leg & hand bitten        N      12h30
# 3856               Shark rammed boat 5 times & holed it        N        NaN
# 3872  Skeletonized, but shark involvement may have o...      NaN        NaN
# 3246                                              FATAL        Y        NaN
# 2347                         Left hand & forearm bitten        N        NaN
# 3690  Minor injury, abdomen abraded when he collided...        N      16h00
# 959                           Lacerations to right foot        N      13h51
# 3620  Right forearm severed, right leg bitten and su...        N      14h00
# 126                                    Left foot bitten        N        NaN
# 4916              Calf & shin bitten  PROVOKED INCIDENT        N        NaN
# 3346                       Right hand & torso lacerated        N        NaN
# 5203          No injury to occupants, shark rammed boat        N        NaN
# 4808  Laceration to left foot & ankle by netted shar...        N  Afternoon
# 2720                                       Thigh bitten        N      09h30
# 3107  FATAL, disappeared while fishing from shore, d...        Y        NaN
# 4044                               Right foot lacerated        N      07h30
# 3734                                Left calf lacerated        N      03h00
#
#                                                 species  \
# 6048                                                NaN
# 4057                                                NaN
# 191                                       a small shark
# 5731       Shark involvement prior to death unconfirmed
# 1129                                           7' shark
# 4522                                        White shark
# 5189       Shark involvement prior to death unconfirmed
# 2472                            3.7 m [12'] white shark
# 4590                                           7' shark
# 1186                           White shark, 4.5 to 5 m
# 2433                                                NaN
# 1638                                        White shark
# 748                                    3.5' to 4' shark
# 2229                            5 m [16.5'] white shark
# 3856                                                NaN
# 3872  Shark involvement prior to death was not confi...
# 3246                                                NaN
# 2347                    1.2 m to 1.5 m [4' to 5'] shark
# 3690                                 1.7 m [5.5'] shark
# 959                                                 NaN
# 3620                                                NaN
# 126                                                 NaN
# 4916                                  "Blue nose shark"
# 3346                         1.8 m [6'] grey reef shark
# 5203                                                NaN
# 4808                                    Tiger shark, 6'
# 2720               2.4 m to 3 m [8' to 10'] white shark
# 3107                                                NaN
# 4044                                    "a small shark"
# 3734  Dooley believed his Injury was caused by sting...
#
#                                  investigator_or_source  \
# 6048           Report of the loss of the Somers, J.H.W.
# 4057                            Manila Times, 10/2/1959
# 191                               Perth Now, 12/28/2016
# 5731                          New York Times, 6/18/1888
# 1129                             Sun Sentinel, 5/8/2009
# 4522            A. De Maddalena; V. Biagi (pers. Comm.)
# 5189                                         11/02/1924
# 2472                           Tampa Tribune, 9/18/1993
# 4590                       V.M. Coppleson (1958), p.181
# 1186                                        S. Chenhall
# 2433    C. Lancaster, Orlando Sentinel,  6/1/1994, p.C1
# 1638        S. Mead, R. Collier, J. Eager, B. Middleton
# 748                                      WYTV, 9/3/2012
# 2229                             R. Collier, pp.159-160
# 3856                                         T. Wallett
# 3872                              H.D. Baldridge, p.162
# 3246                         Reunion Marine Observatory
# 2347                      Fort Pierce Tribune, 9/1/1995
# 3690                            Sun Sentinel, 3/6/1964
# 959                               Maui News, 12/14/2010
# 3620  J. Carranza (This is apparently a different ca...
# 126                                   C. Creswell, GSAF
# 4916                                       G.P. Whitley
# 3346                               G. Ambrose, pp.78-86
# 5203                NY Herald Tribune, undated clipping
# 4808                             Cairns Post, 10/6/1938
# 2720                             R. Collier, pp.102-104
# 3107        J. Borg, p.74; L. Taylor (1993), pp.104-105
# 4044                 Sunday Mail (Brisbane), 11/29/1959
# 3734            R. Yalap, M.D.; H.D. Baldridge, p..104
#
#                                                    href  original_order
# 6048  http://sharkattackfile.net/spreadsheets/pdf_di...           255.0
# 4057  http://sharkattackfile.net/spreadsheets/pdf_di...          2246.0
# 191   http://sharkattackfile.net/spreadsheets/pdf_di...          6112.0
# 5731  http://sharkattackfile.net/spreadsheets/pdf_di...           572.0
# 1129  http://sharkattackfile.net/spreadsheets/pdf_di...          5174.0
# 4522  http://sharkattackfile.net/spreadsheets/pdf_di...          1781.0
# 5189  http://sharkattackfile.net/spreadsheets/pdf_di...          1114.0
# 2472  http://sharkattackfile.net/spreadsheets/pdf_di...          3831.0
# 4590  http://sharkattackfile.net/spreadsheets/pdf_di...          1713.0
# 1186  http://sharkattackfile.net/spreadsheets/pdf_di...          5117.0
# 2433  http://sharkattackfile.net/spreadsheets/pdf_di...          3870.0
# 1638  http://sharkattackfile.net/spreadsheets/pdf_di...          4665.0
# 748   http://sharkattackfile.net/spreadsheets/pdf_di...          5555.0
# 2229  http://sharkattackfile.net/spreadsheets/pdf_di...          4074.0
# 3856  http://sharkattackfile.net/spreadsheets/pdf_di...          2447.0
# 3872  http://sharkattackfile.net/spreadsheets/pdf_di...          2431.0
# 3246  http://sharkattackfile.net/spreadsheets/pdf_di...          3057.0
# 2347  http://sharkattackfile.net/spreadsheets/pdf_di...          3956.0
# 3690  http://sharkattackfile.net/spreadsheets/pdf_di...          2613.0
# 959   http://sharkattackfile.net/spreadsheets/pdf_di...          5344.0
# 3620  http://sharkattackfile.net/spreadsheets/pdf_di...          2683.0
# 126   http://sharkattackfile.net/spreadsheets/pdf_di...          6177.0
# 4916  http://sharkattackfile.net/spreadsheets/pdf_di...          1387.0
# 3346  http://sharkattackfile.net/spreadsheets/pdf_di...          2957.0
# 5203  http://sharkattackfile.net/spreadsheets/pdf_di...          1100.0
# 4808  http://sharkattackfile.net/spreadsheets/pdf_di...          1495.0
# 2720  http://sharkattackfile.net/spreadsheets/pdf_di...          3583.0
# 3107  http://sharkattackfile.net/spreadsheets/pdf_di...          3196.0
# 4044  http://sharkattackfile.net/spreadsheets/pdf_di...          2259.0
# 3734  http://sharkattackfile.net/spreadsheets/pdf_di...          2569.0

# %% [markdown]
# ## Type
#
# We start cleaning more in depth by looking at the type column.

# %%
# We check the values for 'type'
df["type"].value_counts(dropna=False)
# Out:
# Unprovoked      4562
# Provoked         571
# Invalid          542
# Sea Disaster     231
# Boating          202
# Boat             137
# NaN                4
# Questionable       2
# Boatomg            1
# Name: type, dtype: int64

# %%
# Change invalid and questionable to NaN
df["type"].replace(["Invalid", "Questionable"], np.nan, inplace=True)

# And merge boating
df["type"].replace(["Boat", "Boatomg"], "Boating", inplace=True)

df["type"].value_counts(dropna=False)
# Out:
# Unprovoked      4562
# Provoked         571
# NaN              548
# Boating          340
# Sea Disaster     231
# Name: type, dtype: int64

# %% [markdown]
# ## Date
# Next we look at the date.

# %%
# Change date to datetime column
df.date = pd.to_datetime(df["date"], errors="coerce", )
df.head()
# Out:
#         date        type    country             area  \
# 0 2018-06-25     Boating        USA       California
# 1 2018-06-18  Unprovoked        USA          Georgia
# 2 2018-06-09         NaN        USA           Hawaii
# 3 2018-06-08  Unprovoked  AUSTRALIA  New South Wales
# 4 2018-06-04    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#            species          investigator_or_source  \
# 0      White shark                R. Collier, GSAF
# 1              NaN  K.McMurray, TrackingSharks.com
# 2              NaN  K.McMurray, TrackingSharks.com
# 3        2 m shark                  B. Myatt, GSAF
# 4  Tiger shark, 3m                       A .Kipper
#
#                                                 href  original_order
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6303.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6302.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6301.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6300.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6299.0

# %%
# Get rid of future dates. Doesn't work because of 20 rows that aren't yet in date format it seems.
#df["date"] = df["date"].apply(invalid_year)
df.date.isna().values.sum()
# Out:
# 821

# %% [markdown]
# ## Activity column
# This column takes a lot more work. There are many different values, more than 1500. We will try to use combine them to bring it down to 120.

# %%
df["activity"].value_counts()
# Out:
# Surfing                                                                                                                                                                                      970
# Swimming                                                                                                                                                                                     862
# Fishing                                                                                                                                                                                      431
# Spearfishing                                                                                                                                                                                 332
# Bathing                                                                                                                                                                                      160
#                                                                                                                                                                                             ...
# Bitten while cutting shark from net                                                                                                                                                            1
# Diving for trochus  from dinghy when seized by shark 6' below the surface                                                                                                                      1
# Cargo ship El Gamil entroute Suez to Yemen (Aden) when her cargo shifted and she sank. 19 Egyption sailors jumped into the water and swam for several hours before being bitten by sharks      1
# Diving for trochus , but swimming on surface                                                                                                                                                   1
# Bottom fishing for lingcod & had hooked a fish                                                                                                                                                 1
# Name: activity, Length: 1513, dtype: int64

# %%
# Let's check what values we have in this column
df["activity"].unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
# Key is category, list in dict-value are search patterns
regex_dict = {"shipwreck": ["wreck", "sea disaster", "battle", 
                            "sunk", "sank", "capsiz", "swamped",
                            "burning", "Fell", "adrift", "washed",
                            "overboard", "thrown", "sink", "swept",
                            "murder", "explosion", "freighter", "tanker",
                            "founder", "steam", "submarine", "torped",
                            "destroy", "collided", "drown", "desert",
                            "accident", "disappear", "dinghy", "raft"],
              "beach activity": [r"sta.*ding", "wading", "walking", 
                                 "gathering", "lying", "splash", "playing",
                                 "wading", "inflat", "sitting"],
              "shark handling": ["shark"],
              "surfing": ["surfboard", r"surf[a-z]?ng", "kite", r"sup\b", 
                          "boardi", "paddling"],
              "aircrash": ["airc", "air disaster", "air/sea disaster", 
                           "airlin", r"air.*force", "plane", "boeing"], 
              "canoeing": [r".*skiing", "canoe", "kayak"],
              "fishing": [r"fish[a-z]*", "hunting", "spear", "netting", "prawn",
                          "harpoo", "lobster", "crab", "collecting", "shrimp",
                          "oyster", "sardine", "hauling", "casting", "catching"],
              "washing": [r"wash[^e]"],
              "swimming": ["swimming", "treading", "dived", r"swim", 
                           "bathing", "floating", "jump", "kneeling"],
              "boating": ["boating", "sailing", "rowing", "cruising", "yacht"],
              "diving": ["diving", "snorkeling", "diver"],
              "research": ["photo", "film", "research", "scient"],
              np.NaN: ["unknown"]}

for k, v in regex_dict.items():
    search_and_set(df, "activity", k, regex=True, lst=v)

# %%
# Check the result
df["activity"].nunique()
# Out:
# 122

# %% [markdown]
# ## Sex column
# This column is fairly straight forward. We can combine into M or F

# %%
# What unique values we have at first
df["sex"].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
# Anything that's not F or M will be set to NaN
search_and_set(df, "sex", np.NaN, lst=[r"[^FM]"])
df["sex"].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %% [markdown]
# ## Name column
# We follow a similar process, but need to account for the fact that some names feature a '.' or ','.

# %%
df["name"].value_counts()
# Out:
# male                 542
# female                97
# boy                   23
# boat                  14
# 2 males               14
#                     ...
# Geeteh Toussaint       1
# Damien Johnson         1
# Zebulon Critchlow      1
# Ryan Eckstrum          1
# Kenneth Hall           1
# Name: name, Length: 5196, dtype: int64

# %%
# First change how Jr is written, so we can check for punctuation later
regex_pat = re.compile(r"[,]* jr[.]*")
df["name"] = (df["name"]
              .str.lower()
              .str.strip()
              .str.replace(regex_pat, " jr", regex=True))

# Now remove everything with punctuation
search_and_set(df, "name", np.NaN, regex=True, 
               lst=[r"\d", r"\ba\s[a-z]*", "male", r"[,:;]"])

# And remove all single 'names'
df["name"] = df["name"].str.title().apply(regex_test, args=(r"[ ]", ))

# %% [markdown]
# ## Age
# For age we decide only to keep values that are 1 or 2 digits. As well we change the dtype to int.

# %%
# Next we clean up the age column
df.age.value_counts()
# Out:
# 17             154
# 18             150
# 19             142
# 15             139
# 20             139
#               ...
# 81               1
#  28              1
# ?    &   14      1
# 36 & 26          1
# 17 & 16          1
# Name: age, Length: 157, dtype: int64

# %%
# First correct for babies
search_and_set(df, "age", "1", lst=["month"])
# Now if we find 1 or 2 digits we keep that value. 
df["age"] = df["age"].str.strip().apply(regex_test, args=(r"\d{1,2}", True))

# %%
# Now we've cleared bogus values, we can convert to integer
df["age"] = df["age"].fillna(0).astype(int)

# %% [markdown]
# ## Fatal_yn
# This column is fairly straight forward, and we can just use the method we used earlier as well.

# %%
df.fatal_yn.unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
regex_dict = {np.NaN: ["unknown", "2017"],
         "N": ["n", "m"],
         "Y": ["y"]
        }
for k,v in regex_dict.items():
    search_and_set(df, "fatal_yn", k, regex=True, lst=v)

# %% [markdown]
# ## Setting a new index
#
# If original_order is unique then we can use it as an index

# %%
df["original_order"].value_counts(dropna=False)
# Out:
# 569.0     2
# 3854.0    1
# 725.0     1
# 708.0     1
# 590.0     1
#          ..
# 3106.0    1
# 3080.0    1
# 2812.0    1
# 2712.0    1
# 6272.0    1
# Name: original_order, Length: 6251, dtype: int64

# %%
# There are 2 rows with number 569. The highest value is 6303, so we change one of the 2 to 6304.

df.loc[(df["original_order"] == 569) & (df["type"] == "Unprovoked"), "original_order"] = 6304

# %%
# Getting rid of empty rows
df["original_order"].dropna(inplace=True)

# %%
# We change the column dtype to int
df["original_order"] = df["original_order"].astype(int)

# %%
# Now the original_order is unique, we can use it as an index
df.set_index("original_order", inplace=True)
df.head()
# Out:
#                      date        type    country             area  \
# original_order
# 6303           2018-06-25     Boating        USA       California
# 6302           2018-06-18  Unprovoked        USA          Georgia
# 6301           2018-06-09         NaN        USA           Hawaii
# 6300           2018-06-08  Unprovoked  AUSTRALIA  New South Wales
# 6299           2018-06-04    Provoked     MEXICO           Colima
#
#                                       location        activity           name  \
# original_order
# 6303               Oceanside, San Diego County         surfing    Julie Wolfe
# 6302            St. Simon Island, Glynn County  beach activity            NaN
# 6301                              Habush, Oahu         surfing    John Denges
# 6300                        Arrawarra Headland         surfing            NaN
# 6299                                  La Ticla          diving  Gustavo Ramos
#
#                sex  age                                             injury  \
# original_order
# 6303             F   57  No injury to occupant, outrigger canoe and pad...
# 6302             F   11                         Minor injury to left thigh
# 6301             M   48       Injury to left lower leg from surfboard skeg
# 6300             M    0                          Minor injury to lower leg
# 6299             M    0  Lacerations to leg & hand shark PROVOKED INCIDENT
#
#                fatal_yn           time          species  \
# original_order
# 6303                  N          18h00      White shark
# 6302                  N  14h00  -15h00              NaN
# 6301                  N          07h45              NaN
# 6300                  N            NaN        2 m shark
# 6299                  N            NaN  Tiger shark, 3m
#
#                         investigator_or_source  \
# original_order
# 6303                          R. Collier, GSAF
# 6302            K.McMurray, TrackingSharks.com
# 6301            K.McMurray, TrackingSharks.com
# 6300                            B. Myatt, GSAF
# 6299                                 A .Kipper
#
#                                                              href
# original_order
# 6303            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6302            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299            http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# ## Export
# Now that the dataset is a lot cleaner, we will save it as a new csv-file.

# %%
df.to_csv("cleaned_sharks.csv")
